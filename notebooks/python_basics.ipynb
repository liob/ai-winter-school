# %% [markdown]
# ![xkcd python](https://imgs.xkcd.com/comics/python.png)
# source: [XKCD](https://xkcd.com/353/)

# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Numbers

# %%
# integer
1 + 2
# Out:
# 3

# %%
# assigning a variable
a = 1

# float
b = 2.5

a + b
# Out:
# 3.5

# %%
# exponentiation (x^y)
b**2
# Out:
# 6.25

# %% [markdown]
# ## String

# %%
s = 'Hello World'
s
# Out:
# 'Hello World'

# %% [markdown]
# ## Array

# %%
ar = ['1', 2, b, 1+2]
ar
# Out:
# ['1', 2, 2.5, 3]

# %%
ar[1:]
# Out:
# [2, 2.5, 3]

# %%
sum(ar[1:])
# Out:
# 7.5

# %% [markdown]
# # Functions

# %%
def square(x):
  return x**2

square(9)
# Out:
# 81

# %% [markdown]
# # Import Modules
#
# ![python ecosystem](http://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1509622333/scipy-eco_kqi2su.png)
# source: [datacamp.com](https://www.datacamp.com/community/blog/python-scientific-computing-case)

# %%
# %tensorflow_version 2.x
# %matplotlib inline

import numpy as np                     # array goodnes
from pandas import DataFrame, read_csv # excel for python
from tensorflow.keras.utils import get_file       # handy function to download data
from matplotlib import pyplot as plt   # plotting library
import seaborn as sns                  # more plotting stuff

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## Numpy

# %%
a = np.array([2, b, 1+2])
print('mean:', np.mean(a), 'sd:', np.std(a), 'median:', np.median(a))
print('min:', np.min(a), 'max:', np.max(a), 'sum:', np.sum(a))
# Out:
# mean: 2.5 sd: 0.408248290463863 median: 2.5
# min: 2.0 max: 3.0 sum: 7.5

# %% [markdown]
# # Use Case - Loading and Processing Data (Linear Regression)

# %% [markdown]
# ## Load Data
#
# The Iris dataset
# ![iris](https://raw.githubusercontent.com/ritchieng/machine-learning-dataschool/master/images/03_iris.png)
#
#   - 50 samples of 3 different species (150 samples total)
#   - Measurements: sepal length, sepal width, petal length, petal width

# %%
fn_iris = get_file('iris.csv', 'https://raw.githubusercontent.com/liob/ai-winther-school/master/data/iris.csv')
df_iris = read_csv(fn_iris)
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(data=df_iris, hue='species', diag_kind='kde')

# %% [markdown]
# ## Linear Model

# %%
X_iris = df_iris.drop('species', axis=1)
Y_iris = df_iris['species']

# %%
X = X_iris['sepal_length']
Y = X_iris['petal_length']

mask = Y_iris == 'virginica'
X = X[mask]
Y = Y[mask]

plt.scatter(X, Y, label='virginica')
plt.xlabel('sepal length')
plt.ylabel('petal length')
plt.legend()

# %% [markdown]
# # HANDS ON: Linear Regression
#
# ![](https://www.wired.com/images_blogs/wiredscience/2011/01/Untitled3.jpg)
#
# Given a model function
# $$
# y = \alpha + \beta x~,
# $$
# where $\alpha$ is defined as
# $$
# \alpha = \frac{\sum\nolimits_{i=1}^n(x_i - \bar{x})(y_i - \bar{y})}
#                      {\sum\nolimits_{i=1}^n(x_i - \bar{x})^2}
# $$
# and $\beta$ is defined as
# $$
# \beta = \bar{y} - \alpha \bar{x}~.
# $$
# $\alpha$ and $\beta$ are also known as slope and intercept.
#
#
# # Task
# Model a linear regression to fit sepal length and pepal length of the virginica species. The required data points are represented by the variables X (sepal length) and Y (pepal length).
#
# | Math | Op |
# | ---------| -----|
# | sum | np.sum |
# |mean | np.mean |
# | exponentiation | x**y |

# %%
###################
#                 #
# YOUR CODE HERE! #
#                 #
###################

# %%
# code for plotting your results

slope = 1.0
intercept = 0.0

plt.scatter(X, Y, label='Iris-virginica') # plot data points
plt.plot((5,8), (5*slope+intercept, 8*slope+intercept), 
         label='linear regression', c='green')
plt.legend()
